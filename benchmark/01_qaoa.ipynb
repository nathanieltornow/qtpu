# %%
import os
import pandas as pd
import optuna
from qiskit.circuit import QuantumCircuit

import qtpu

from benchmark._plot_util import *

# %%
# NUM_QUBITS = 100

SUBCIRCUIT_SIZE = 15
CSV_FILE = "qaoa_cost.csv"

# %%
from qtpu.compiler.compiler import compile_reach_size
from benchmark.ckt import cut_ckt, run_ckt
from benchmark.util import ckt_cost, qtpu_cost, get_info
import time
from qiskit_aer.primitives import Sampler

# %%
from benchmark.ansatz import qaoa, generate_clustered_graph, generate_seperator_graph


def generate_bench(name: str, r: int, n: int, m: int, reps: int) -> QuantumCircuit:
    func = generate_seperator_graph if name == "qaoa1" else generate_clustered_graph
    return qaoa(func(r, n, m), reps)


BENCHMARKS = [
    {"name": name, "r": r, "n": 10, "m": 2, "reps": 1}
    for r in range(2, 11)
    for name in ["qaoa1", "qaoa2"]
    # {"name": "qaoa1", "r": 3, "n": 10, "m": 2, "reps": 2},
    # {"name": "qaoa1", "r": 4, "n": 10, "m": 2, "reps": 2},
    # {"name": "qaoa1", "r": 5, "n": 10, "m": 2, "reps": 2},
    # {"name": "qaoa2", "r": 2, "n": 10, "m": 2, "reps": 2},
]

# %%
from benchmark.util import append_to_csv


for bench in BENCHMARKS:
    circuit = generate_bench(**bench)

    qtpu_circuit = compile_reach_size(
        circuit,
        SUBCIRCUIT_SIZE,
        show_progress_bar=True,
    )

    info = get_info(qtpu_circuit)

    append_to_csv(CSV_FILE, {**bench, **info})
# Out:
# [[20, 21]]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [FrozenTrial(number=3, state=1, values=[256.0, 0.9896533783548956], datetime_start=datetime.datetime(2024, 8, 12, 12, 50, 28, 192985), datetime_complete=datetime.datetime(2024, 8, 12, 12, 50, 28, 208373), params={'compress': '2q', 'choose_leaf': 'qubits', 'random_strength': 5.561831244680146, 'weight_edges': 'const', 'imbalance': 0.3950778545533015, 'imbalance_decay': -0.34044282491040967, 'parts': 7, 'parts_decay': 0.5749903915144798, 'mode': 'recursive', 'objective': 'km1', 'fix_output_nodes': 'auto'}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8c67d14590>, 'tree': <ContractionTree(N=144, branches=1, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=3, value=None), FrozenTrial(number=11, state=1, values=[256.0, 0.9896533783548956], datetime_start=datetime.datetime(2024, 8, 12, 12, 50, 28, 347249), datetime_complete=datetime.datetime(2024, 8, 12, 12, 50, 28, 362038), params={'compress': '2q', 'choose_leaf': 'qubits', 'random_strength': 4.8615242260384814, 'weight_edges': 'log', 'imbalance': 0.17731371355315448, 'imbalance_decay': 1.352975195361216, 'parts': 6, 'parts_decay': 0.5596986694079674, 'mode': 'direct', 'objective': 'cut', 'fix_output_nodes': 'auto'}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8c67da05d0>, 'tree': <ContractionTree(N=144, branches=1, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=11, value=None), FrozenTrial(number=13, state=1, values=[256.0, 0.9896533783548956], datetime_start=datetime.datetime(2024, 8, 12, 12, 50, 28, 433947), datetime_complete=datetime.datetime(2024, 8, 12, 12, 50, 28, 448136), params={'compress': '2q', 'choose_leaf': 'qubits', 'random_strength': 2.1235099671285917, 'weight_edges': 'const', 'imbalance': 0.1742101652685807, 'imbalance_decay': 1.490023745322465, 'parts': 4, 'parts_decay': 0.30987605204985924, 'mode': 'direct', 'objective': 'cut', 'fix_output_nodes': 'auto'}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8c67c20990>, 'tree': <ContractionTree(N=144, branches=1, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': Ca ...
# [256.0, 0.9896533783548956]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [FrozenTrial(number=0, state=1, values=[8.0, 0.9914364478720087], datetime_start=datetime.datetime(2024, 8, 12, 12, 50, 38, 786042), datetime_complete=datetime.datetime(2024, 8, 12, 12, 50, 38, 791980), params={'compress': 'qubits', 'choose_leaf': 'qubits', 'random_strength': 8.93875312717152, 'weight_edges': 'const', 'imbalance': 0.7680551208679042, 'imbalance_decay': -3.3966149706702673, 'parts': 14, 'parts_decay': 0.6943918539157231, 'mode': 'direct', 'objective': 'cut', 'fix_output_nodes': 'auto'}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8c66ac6650>, 'tree': <ContractionTree(N=20, branches=1, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=0, value=None), FrozenTrial(number=2, state=1, values=[9232.0, 0.991932314846119], datetime_start=datetime.datetime(2024, 8, 12, 12, 50, 38, 909293), datetime_complete=datetime.datetime(2024, 8, 12, 12, 50, 38, 937854), params={'compress': '2q', 'choose_leaf': 'qubits', 'random_strength': 9.3345834951874, 'weight_edges': 'log', 'imbalance': 0.6823011981554684, 'imbalance_decay': -2.8683023179307066, 'parts': 8, 'parts_decay': 0.10224322450053147, 'mode': 'direct', 'objective': 'cut', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8c669ec9d0>, 'tree': <ContractionTree(N=122, branches=7, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=2, value=None), FrozenTrial(number=5, state=1, values=[8.0, 0.9914364478720087], datetime_start=datetime.datetime(2024, 8, 12, 12, 50, 39, 231673), datetime_complete=datetime.datetime(2024, 8, 12, 12, 50, 39, 243573), params={'compress': 'none', 'choose_leaf': 'qubits', 'random_strength': 3.4640771314491574, 'weight_edges': 'log', 'imbalance': 0.04298265689002682, 'imbalance_decay': -1.4912979723794404, 'parts': 9, 'parts_decay': 0.5762331058744244, 'mode': 'recursive', 'objective': 'km1', 'fix_output_nodes': 'auto'}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8c66c35110>, 'tree': <ContractionTree(N=166, branches=1, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': Categorica ...
# [8.0, 0.9914364478720087]
# [[30, 31], [32, 33]]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [FrozenTrial(number=9, state=1, values=[16448.0, 0.9894554575757585], datetime_start=datetime.datetime(2024, 8, 12, 12, 50, 45, 898633), datetime_complete=datetime.datetime(2024, 8, 12, 12, 50, 45, 937172), params={'compress': 'none', 'choose_leaf': 'qubits', 'random_strength': 2.4662964479403042, 'weight_edges': 'log', 'imbalance': 0.17457462662005033, 'imbalance_decay': 1.587276973565964, 'parts': 5, 'parts_decay': 0.18388089661867835, 'mode': 'direct', 'objective': 'cut', 'fix_output_nodes': 'auto'}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a5919e110>, 'tree': <ContractionTree(N=308, branches=2, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=9, value=None), FrozenTrial(number=22, state=1, values=[359564436.0, 0.9910399327750811], datetime_start=datetime.datetime(2024, 8, 12, 12, 50, 47, 915032), datetime_complete=datetime.datetime(2024, 8, 12, 12, 50, 47, 939764), params={'compress': 'qubits', 'choose_leaf': 'qubits', 'random_strength': 8.54544467613795, 'weight_edges': 'log', 'imbalance': 0.310929956811627, 'imbalance_decay': 4.190325278017616, 'parts': 11, 'parts_decay': 0.6364499977137973, 'mode': 'direct', 'objective': 'cut', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a58d1bd90>, 'tree': <ContractionTree(N=34, branches=9, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=22, value=None), FrozenTrial(number=29, state=1, values=[135440.0, 0.989851338724127], datetime_start=datetime.datetime(2024, 8, 12, 12, 50, 50, 430104), datetime_complete=datetime.datetime(2024, 8, 12, 12, 50, 50, 484690), params={'compress': 'none', 'choose_leaf': 'qubits', 'random_strength': 1.0585654874827242, 'weight_edges': 'const', 'imbalance': 0.2947971115367706, 'imbalance_decay': 3.9545354552777496, 'parts': 6, 'parts_decay': 0.036062631632722275, 'mode': 'direct', 'objective': 'cut', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8ae01bbc90>, 'tree': <ContractionTree(N=308, branches=5, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': ...
# [16448.0, 0.9894554575757585]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [FrozenTrial(number=3, state=1, values=[8448.0, 0.9914364478720087], datetime_start=datetime.datetime(2024, 8, 12, 12, 51, 8, 128216), datetime_complete=datetime.datetime(2024, 8, 12, 12, 51, 8, 154537), params={'compress': '2q', 'choose_leaf': 'qubits', 'random_strength': 9.646691886572416, 'weight_edges': 'const', 'imbalance': 0.4007242760347294, 'imbalance_decay': -0.2982913752569267, 'parts': 6, 'parts_decay': 0.23986693739268972, 'mode': 'recursive', 'objective': 'km1', 'fix_output_nodes': 'auto'}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a32470490>, 'tree': <ContractionTree(N=182, branches=2, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=3, value=None), FrozenTrial(number=5, state=1, values=[314168123920.0, 0.9959081893501199], datetime_start=datetime.datetime(2024, 8, 12, 12, 51, 8, 178964), datetime_complete=datetime.datetime(2024, 8, 12, 12, 51, 8, 264262), params={'compress': 'none', 'choose_leaf': 'qubits', 'random_strength': 2.0267440306127718, 'weight_edges': 'log', 'imbalance': 0.08320286723986, 'imbalance_decay': 1.6710833314419045, 'parts': 11, 'parts_decay': 0.3554977945669108, 'mode': 'direct', 'objective': 'km1', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a32ab9ed0>, 'tree': <ContractionTree(N=248, branches=10, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=5, value=None), FrozenTrial(number=7, state=1, values=[330.0, 0.9909408287818036], datetime_start=datetime.datetime(2024, 8, 12, 12, 51, 8, 447222), datetime_complete=datetime.datetime(2024, 8, 12, 12, 51, 8, 479131), params={'compress': 'none', 'choose_leaf': 'qubits', 'random_strength': 3.30286449734942, 'weight_edges': 'log', 'imbalance': 0.37708972097347254, 'imbalance_decay': 4.213101603404148, 'parts': 14, 'parts_decay': 0.5305882259306107, 'mode': 'direct', 'objective': 'km1', 'fix_output_nodes': 'auto'}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8c66c2e410>, 'tree': <ContractionTree(N=248, branches=2, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': Cate ...
# [190.0, 0.9908417346989254]
# [[40, 41], [42, 43], [44, 45]]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [FrozenTrial(number=0, state=1, values=[2747.0, 0.9890597347560979], datetime_start=datetime.datetime(2024, 8, 12, 12, 51, 22, 509427), datetime_complete=datetime.datetime(2024, 8, 12, 12, 51, 22, 643491), params={'compress': 'qubits', 'choose_leaf': 'qubits', 'random_strength': 4.345633775644576, 'weight_edges': 'log', 'imbalance': 0.9613575963860058, 'imbalance_decay': -4.74798617273101, 'parts': 15, 'parts_decay': 0.8268139744274046, 'mode': 'direct', 'objective': 'cut', 'fix_output_nodes': 'auto'}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a32b4d250>, 'tree': <ContractionTree(N=46, branches=3, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=0, value=None), FrozenTrial(number=4, state=1, values=[882047249953552.0, 0.9954103348363053], datetime_start=datetime.datetime(2024, 8, 12, 12, 51, 23, 325388), datetime_complete=datetime.datetime(2024, 8, 12, 12, 51, 23, 489478), params={'compress': '2q', 'choose_leaf': 'qubits', 'random_strength': 0.34514807688144966, 'weight_edges': 'const', 'imbalance': 0.8119156640362608, 'imbalance_decay': 3.0177334286508284, 'parts': 15, 'parts_decay': 0.8120071633035141, 'mode': 'recursive', 'objective': 'km1', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a32876750>, 'tree': <ContractionTree(N=294, branches=23, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=4, value=None), FrozenTrial(number=21, state=1, values=[2747.0, 0.9890597347560979], datetime_start=datetime.datetime(2024, 8, 12, 12, 51, 28, 553730), datetime_complete=datetime.datetime(2024, 8, 12, 12, 51, 28, 574424), params={'compress': 'qubits', 'choose_leaf': 'qubits', 'random_strength': 1.2686765437620164, 'weight_edges': 'log', 'imbalance': 0.8683587867751736, 'imbalance_decay': -4.530438807178849, 'parts': 3, 'parts_decay': 0.21712768669397386, 'mode': 'direct', 'objective': 'km1', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a32c99250>, 'tree': <ContractionTree(N=46, branches=3, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_ ...
# [1863.0, 0.9888619326997441]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [FrozenTrial(number=8, state=1, values=[318.0, 0.9904454574515867], datetime_start=datetime.datetime(2024, 8, 12, 12, 51, 48, 527158), datetime_complete=datetime.datetime(2024, 8, 12, 12, 51, 48, 544163), params={'compress': 'qubits', 'choose_leaf': 'qubits', 'random_strength': 2.895764015825719, 'weight_edges': 'log', 'imbalance': 0.26070597152316655, 'imbalance_decay': -2.045151211627384, 'parts': 3, 'parts_decay': 0.0809628459452656, 'mode': 'direct', 'objective': 'cut', 'fix_output_nodes': 'auto'}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a3140d610>, 'tree': <ContractionTree(N=40, branches=3, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=8, value=None), FrozenTrial(number=23, state=1, values=[2167824.0, 0.9910399327750811], datetime_start=datetime.datetime(2024, 8, 12, 12, 51, 50, 16982), datetime_complete=datetime.datetime(2024, 8, 12, 12, 51, 50, 98257), params={'compress': '2q', 'choose_leaf': 'qubits', 'random_strength': 8.306608394189684, 'weight_edges': 'const', 'imbalance': 0.8276197345286578, 'imbalance_decay': -2.09536085351947, 'parts': 8, 'parts_decay': 0.3074379355983725, 'mode': 'recursive', 'objective': 'km1', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a32e6cd10>, 'tree': <ContractionTree(N=251, branches=12, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=23, value=None), FrozenTrial(number=25, state=1, values=[2624125159866384.0, 0.9971040563483742], datetime_start=datetime.datetime(2024, 8, 12, 12, 51, 50, 862980), datetime_complete=datetime.datetime(2024, 8, 12, 12, 51, 50, 981016), params={'compress': 'none', 'choose_leaf': 'qubits', 'random_strength': 3.278117179877742, 'weight_edges': 'const', 'imbalance': 0.014124136143186902, 'imbalance_decay': 0.41412906448683007, 'parts': 13, 'parts_decay': 0.9501034338545997, 'mode': 'recursive', 'objective': 'cut', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a31baab90>, 'tree': <ContractionTree(N=346, branches=12, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), ' ...
# [318.0, 0.9904454574515867]
# [[50, 51], [52, 53], [54, 55], [56, 57]]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [FrozenTrial(number=2, state=1, values=[1714954256.0, 0.98915865062116], datetime_start=datetime.datetime(2024, 8, 12, 12, 52, 5, 894786), datetime_complete=datetime.datetime(2024, 8, 12, 12, 52, 6, 55818), params={'compress': 'none', 'choose_leaf': 'qubits', 'random_strength': 8.099676539089128, 'weight_edges': 'log', 'imbalance': 0.12307775286843897, 'imbalance_decay': -2.8177943518247037, 'parts': 13, 'parts_decay': 0.22171829466005655, 'mode': 'recursive', 'objective': 'cut', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a32b6f390>, 'tree': <ContractionTree(N=546, branches=12, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=2, value=None), FrozenTrial(number=6, state=1, values=[77551908112.0, 0.990247378264551], datetime_start=datetime.datetime(2024, 8, 12, 12, 52, 8, 847451), datetime_complete=datetime.datetime(2024, 8, 12, 12, 52, 9, 14700), params={'compress': 'none', 'choose_leaf': 'qubits', 'random_strength': 4.564685183270014, 'weight_edges': 'log', 'imbalance': 0.10973225980816591, 'imbalance_decay': 0.03279360394053743, 'parts': 14, 'parts_decay': 0.7253277978802837, 'mode': 'direct', 'objective': 'km1', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a59284e10>, 'tree': <ContractionTree(N=546, branches=13, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=6, value=None), FrozenTrial(number=12, state=1, values=[3.3359335543275776e+16, 0.9943159307794598], datetime_start=datetime.datetime(2024, 8, 12, 12, 52, 12, 272822), datetime_complete=datetime.datetime(2024, 8, 12, 12, 52, 12, 422741), params={'compress': 'none', 'choose_leaf': 'qubits', 'random_strength': 5.761524966940814, 'weight_edges': 'const', 'imbalance': 0.024336163875754442, 'imbalance_decay': 1.738508587310566, 'parts': 11, 'parts_decay': 0.29825267729825555, 'mode': 'recursive', 'objective': 'cut', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a32183f10>, 'tree': <ContractionTree(N=546, branches=10, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step= ...
# [73984.0, 0.9877747282847079]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [FrozenTrial(number=15, state=1, values=[830.0, 0.990643576260403], datetime_start=datetime.datetime(2024, 8, 12, 12, 52, 57, 961085), datetime_complete=datetime.datetime(2024, 8, 12, 12, 52, 57, 979942), params={'compress': 'qubits', 'choose_leaf': 'qubits', 'random_strength': 7.40324268184804, 'weight_edges': 'log', 'imbalance': 0.8554746937704907, 'imbalance_decay': 4.322414167165604, 'parts': 5, 'parts_decay': 0.4196679255751843, 'mode': 'recursive', 'objective': 'km1', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a2a7d7490>, 'tree': <ContractionTree(N=50, branches=4, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=15, value=None), FrozenTrial(number=64, state=1, values=[3179024.0, 0.9914364478720087], datetime_start=datetime.datetime(2024, 8, 12, 12, 53, 8, 106321), datetime_complete=datetime.datetime(2024, 8, 12, 12, 53, 8, 223770), params={'compress': 'none', 'choose_leaf': 'qubits', 'random_strength': 0.01381624340883171, 'weight_edges': 'const', 'imbalance': 0.12559064737348075, 'imbalance_decay': -1.746912409624949, 'parts': 15, 'parts_decay': 0.4680647588502965, 'mode': 'recursive', 'objective': 'cut', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a309df090>, 'tree': <ContractionTree(N=442, branches=14, complete=False)>}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=64, value=None), FrozenTrial(number=66, state=1, values=[830.0, 0.990643576260403], datetime_start=datetime.datetime(2024, 8, 12, 12, 53, 8, 312963), datetime_complete=datetime.datetime(2024, 8, 12, 12, 53, 8, 338964), params={'compress': 'qubits', 'choose_leaf': 'qubits', 'random_strength': 4.1936201343177455, 'weight_edges': 'log', 'imbalance': 0.8069653888260429, 'imbalance_decay': 1.2690917258245786, 'parts': 3, 'parts_decay': 0.9219432241521024, 'mode': 'direct', 'objective': 'km1', 'fix_output_nodes': 'auto'}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a2b412750>, 'tree': <ContractionTree(N=50, branches=4, complete=False)>}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': C ...
# [830.0, 0.990643576260403]
# [[60, 61], [62, 63], [64, 65], [66, 67], [68, 69]]
#   0%|          | 0/100 [00:00<?, ?it/s]
# /home/di75piq/qtpu/.venv/lib/python3.11/site-packages/cotengra/hyperoptimizers/hyper.py:307: UserWarning: Trial error: Optimization timed out. Set `HyperOptimizer` kwarg `on_trial_error='raise'` to raise this error, or `on_trial_error='ignore'` to silence.
#   warnings.warn(
# [FrozenTrial(number=0, state=1, values=[1.847379755597842e+17, 0.9889608287826224], datetime_start=datetime.datetime(2024, 8, 12, 12, 53, 15, 981589), datetime_complete=datetime.datetime(2024, 8, 12, 12, 53, 16, 247924), params={'compress': '2q', 'choose_leaf': 'qubits', 'random_strength': 6.0212191746123995, 'weight_edges': 'log', 'imbalance': 0.7747061847521257, 'imbalance_decay': 2.3085339013926562, 'parts': 14, 'parts_decay': 0.5175119051672297, 'mode': 'recursive', 'objective': 'cut', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8c671b0bd0>, 'tree': <ContractionTree(N=477, branches=23, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=0, value=None), FrozenTrial(number=40, state=1, values=[262400.0, 0.9874784254984765], datetime_start=datetime.datetime(2024, 8, 12, 12, 53, 39, 39006), datetime_complete=datetime.datetime(2024, 8, 12, 12, 53, 39, 149483), params={'compress': 'none', 'choose_leaf': 'qubits', 'random_strength': 0.4573048731992735, 'weight_edges': 'const', 'imbalance': 0.19144492458941254, 'imbalance_decay': -0.3798343520155427, 'parts': 13, 'parts_decay': 0.4858577651511834, 'mode': 'direct', 'objective': 'cut', 'fix_output_nodes': 'auto'}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a3029dd50>, 'tree': <ContractionTree(N=686, branches=5, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=40, value=None), FrozenTrial(number=43, state=1, values=[262400.0, 0.9874784254984765], datetime_start=datetime.datetime(2024, 8, 12, 12, 53, 40, 254286), datetime_complete=datetime.datetime(2024, 8, 12, 12, 53, 40, 354866), params={'compress': '2q', 'choose_leaf': 'qubits', 'random_strength': 1.5502052029853124, 'weight_edges': 'const', 'imbalance': 0.24224423173768186, 'imbalance_decay': 0.5641432383253688, 'parts': 3, 'parts_decay': 0.6266122177111907, 'mode': 'direct', 'objective': 'cut', 'fix_output_nodes': 'auto'}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a32adc990>, 'tree': <ContractionTree(N=477, branches=5, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=N ...
# [172112.0, 0.9871822115941923]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [FrozenTrial(number=2, state=1, values=[10395.0, 0.990643576260403], datetime_start=datetime.datetime(2024, 8, 12, 12, 54, 20, 530704), datetime_complete=datetime.datetime(2024, 8, 12, 12, 54, 20, 557562), params={'compress': 'qubits', 'choose_leaf': 'qubits', 'random_strength': 6.201965125326177, 'weight_edges': 'log', 'imbalance': 0.08314336668935249, 'imbalance_decay': -1.4435428776586248, 'parts': 6, 'parts_decay': 0.5168718558747029, 'mode': 'recursive', 'objective': 'cut', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8c66ed90d0>, 'tree': <ContractionTree(N=60, branches=5, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=2, value=None), FrozenTrial(number=17, state=1, values=[10395.0, 0.990643576260403], datetime_start=datetime.datetime(2024, 8, 12, 12, 54, 28, 410955), datetime_complete=datetime.datetime(2024, 8, 12, 12, 54, 28, 436139), params={'compress': 'qubits', 'choose_leaf': 'qubits', 'random_strength': 8.372748189428647, 'weight_edges': 'const', 'imbalance': 0.8920998185052067, 'imbalance_decay': 0.2305457684214538, 'parts': 6, 'parts_decay': 0.7082328595369196, 'mode': 'direct', 'objective': 'km1', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a32792ed0>, 'tree': <ContractionTree(N=60, branches=5, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=17, value=None), FrozenTrial(number=50, state=1, values=[10395.0, 0.990643576260403], datetime_start=datetime.datetime(2024, 8, 12, 12, 54, 41, 532038), datetime_complete=datetime.datetime(2024, 8, 12, 12, 54, 41, 557933), params={'compress': 'qubits', 'choose_leaf': 'qubits', 'random_strength': 7.183158936222539, 'weight_edges': 'const', 'imbalance': 0.4368067950505383, 'imbalance_decay': 0.31322875339819056, 'parts': 6, 'parts_decay': 0.4530597157344668, 'mode': 'recursive', 'objective': 'cut', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a30bcb190>, 'tree': <ContractionTree(N=60, branches=5, complete=False)>}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges':  ...
# [10395.0, 0.990643576260403]
# [[70, 71], [72, 73], [74, 75], [76, 77], [78, 79], [80, 81]]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [FrozenTrial(number=3, state=1, values=[2368545.0, 0.9892575763787979], datetime_start=datetime.datetime(2024, 8, 12, 12, 55, 1, 372786), datetime_complete=datetime.datetime(2024, 8, 12, 12, 55, 1, 512730), params={'compress': '2q', 'choose_leaf': 'qubits', 'random_strength': 0.9474962125324405, 'weight_edges': 'const', 'imbalance': 0.13966874265426785, 'imbalance_decay': -4.665400343564099, 'parts': 12, 'parts_decay': 0.7507388997550617, 'mode': 'recursive', 'objective': 'cut', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a313c2a90>, 'tree': <ContractionTree(N=513, branches=11, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=3, value=None), FrozenTrial(number=17, state=1, values=[92869488568353.0, 0.9910399327750811], datetime_start=datetime.datetime(2024, 8, 12, 12, 55, 7, 387833), datetime_complete=datetime.datetime(2024, 8, 12, 12, 55, 7, 647553), params={'compress': '2q', 'choose_leaf': 'qubits', 'random_strength': 4.573673115273589, 'weight_edges': 'log', 'imbalance': 0.4734655696536805, 'imbalance_decay': 1.9336113795493333, 'parts': 11, 'parts_decay': 0.2735315696700116, 'mode': 'direct', 'objective': 'km1', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a31247b90>, 'tree': <ContractionTree(N=513, branches=24, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=17, value=None), FrozenTrial(number=43, state=1, values=[1.9558490985780637e+17, 0.9960077901291329], datetime_start=datetime.datetime(2024, 8, 12, 12, 55, 19, 638938), datetime_complete=datetime.datetime(2024, 8, 12, 12, 55, 19, 969878), params={'compress': 'none', 'choose_leaf': 'qubits', 'random_strength': 7.764742857580939, 'weight_edges': 'log', 'imbalance': 0.3994400403020082, 'imbalance_decay': 4.316780959647325, 'parts': 16, 'parts_decay': 0.7589573893750313, 'mode': 'direct', 'objective': 'cut', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a2b11e090>, 'tree': <ContractionTree(N=710, branches=29, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), ...
# [143665.0, 0.9890597347560979]
#   0%|          | 0/100 [00:00<?, ?it/s]
# ...
# [397584.0, 0.9884664472544248]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [FrozenTrial(number=9, state=1, values=[4145020967331.0, 0.9922299540664326], datetime_start=datetime.datetime(2024, 8, 12, 12, 59, 51, 858786), datetime_complete=datetime.datetime(2024, 8, 12, 12, 59, 52, 104276), params={'compress': '2q', 'choose_leaf': 'qubits', 'random_strength': 0.502689300528936, 'weight_edges': 'log', 'imbalance': 0.31804176198250683, 'imbalance_decay': 1.7422237417362414, 'parts': 12, 'parts_decay': 0.6710605291170844, 'mode': 'direct', 'objective': 'km1', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a2a8990d0>, 'tree': <ContractionTree(N=570, branches=23, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=9, value=None), FrozenTrial(number=14, state=1, values=[1647167220.0, 0.9908417346989254], datetime_start=datetime.datetime(2024, 8, 12, 12, 59, 54, 648259), datetime_complete=datetime.datetime(2024, 8, 12, 12, 59, 54, 700495), params={'compress': 'qubits', 'choose_leaf': 'qubits', 'random_strength': 0.34322428278491574, 'weight_edges': 'const', 'imbalance': 0.16999854054837674, 'imbalance_decay': -2.830652039037526, 'parts': 6, 'parts_decay': 0.3722587047879252, 'mode': 'recursive', 'objective': 'cut', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8c67103f50>, 'tree': <ContractionTree(N=90, branches=11, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=14, value=None), FrozenTrial(number=47, state=1, values=[177143298.0, 0.9907426505254555], datetime_start=datetime.datetime(2024, 8, 12, 13, 0, 15, 770341), datetime_complete=datetime.datetime(2024, 8, 12, 13, 0, 15, 819969), params={'compress': 'qubits', 'choose_leaf': 'qubits', 'random_strength': 2.000372660662517, 'weight_edges': 'log', 'imbalance': 0.14102810309019473, 'imbalance_decay': -1.5462434718755604, 'parts': 13, 'parts_decay': 0.9018810139435915, 'mode': 'direct', 'objective': 'km1', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a29eb3810>, 'tree': <ContractionTree(N=90, branches=12, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None) ...
# [11706.0, 0.989851338724127]
# [[100, 101], [102, 103], [104, 105], [106, 107], [108, 109], [110, 111], [112, 113], [114, 115], [116, 117]]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [FrozenTrial(number=58, state=1, values=[4.871820003799103e+19, 0.9890597347560979], datetime_start=datetime.datetime(2024, 8, 12, 13, 1, 38, 973313), datetime_complete=datetime.datetime(2024, 8, 12, 13, 1, 39, 228351), params={'compress': 'none', 'choose_leaf': 'qubits', 'random_strength': 2.9680161723503793, 'weight_edges': 'log', 'imbalance': 0.2876245863668882, 'imbalance_decay': 1.734699540898971, 'parts': 12, 'parts_decay': 0.18655549819320738, 'mode': 'direct', 'objective': 'km1', 'fix_output_nodes': 'auto'}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a2b23ab10>, 'tree': <ContractionTree(N=1080, branches=11, complete=False)>}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=58, value=None), FrozenTrial(number=68, state=1, values=[6.053903281233705e+19, 0.9961074008692198], datetime_start=datetime.datetime(2024, 8, 12, 13, 1, 46, 276574), datetime_complete=datetime.datetime(2024, 8, 12, 13, 1, 46, 766578), params={'compress': 'none', 'choose_leaf': 'qubits', 'random_strength': 4.084496850819954, 'weight_edges': 'const', 'imbalance': 0.669100739616908, 'imbalance_decay': 3.665620768408612, 'parts': 14, 'parts_decay': 0.3236612827064337, 'mode': 'direct', 'objective': 'cut', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a29b3f710>, 'tree': <ContractionTree(N=1080, branches=41, complete=False)>}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=68, value=None), FrozenTrial(number=74, state=1, values=[953450512.0, 0.9878735156362715], datetime_start=datetime.datetime(2024, 8, 12, 13, 1, 47, 821095), datetime_complete=datetime.datetime(2024, 8, 12, 13, 1, 48, 200467), params={'compress': 'none', 'choose_leaf': 'qubits', 'random_strength': 6.842296081838449, 'weight_edges': 'const', 'imbalance': 0.13832130967372264, 'imbalance_decay': -0.23041615420009176, 'parts': 14, 'parts_decay': 0.4564069526845014, 'mode': 'recursive', 'objective': 'km1', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a228e0950>, 'tree': <ContractionTree(N=1080, branches=33, complete=False)>}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, l ...
# [17572400.0, 0.9874784254984765]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [FrozenTrial(number=3, state=1, values=[9190.0, 0.990247378264551], datetime_start=datetime.datetime(2024, 8, 12, 13, 2, 13, 335060), datetime_complete=datetime.datetime(2024, 8, 12, 13, 2, 13, 383338), params={'compress': 'qubits', 'choose_leaf': 'qubits', 'random_strength': 6.2448840414749665, 'weight_edges': 'const', 'imbalance': 0.47867198568994174, 'imbalance_decay': 4.15471854270068, 'parts': 10, 'parts_decay': 0.9738685460241716, 'mode': 'direct', 'objective': 'km1', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8c676e4310>, 'tree': <ContractionTree(N=100, branches=9, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=3, value=None), FrozenTrial(number=24, state=1, values=[23380.0, 0.9904454574515867], datetime_start=datetime.datetime(2024, 8, 12, 13, 2, 20, 15165), datetime_complete=datetime.datetime(2024, 8, 12, 13, 2, 20, 200282), params={'compress': 'none', 'choose_leaf': 'qubits', 'random_strength': 7.9286532675767525, 'weight_edges': 'log', 'imbalance': 0.07849877781467376, 'imbalance_decay': 2.151832466087704, 'parts': 12, 'parts_decay': 0.6476729327914222, 'mode': 'recursive', 'objective': 'km1', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a311f0050>, 'tree': <ContractionTree(N=888, branches=11, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges': CategoricalDistribution(choices=('const', 'log')), 'imbalance': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'imbalance_decay': FloatDistribution(high=5.0, log=False, low=-5.0, step=None), 'parts': IntDistribution(high=16, log=False, low=2, step=1), 'parts_decay': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'mode': CategoricalDistribution(choices=('direct', 'recursive')), 'objective': CategoricalDistribution(choices=('cut', 'km1')), 'fix_output_nodes': CategoricalDistribution(choices=('auto', ''))}, trial_id=24, value=None), FrozenTrial(number=26, state=1, values=[12904181776.0, 0.9910399327750811], datetime_start=datetime.datetime(2024, 8, 12, 13, 2, 20, 311589), datetime_complete=datetime.datetime(2024, 8, 12, 13, 2, 20, 498849), params={'compress': '2q', 'choose_leaf': 'qubits', 'random_strength': 2.941811970483283, 'weight_edges': 'const', 'imbalance': 0.03297459273643236, 'imbalance_decay': -0.6538659382568204, 'parts': 16, 'parts_decay': 0.6466726544846755, 'mode': 'recursive', 'objective': 'km1', 'fix_output_nodes': ''}, user_attrs={'ir': <qtpu.compiler.compress.CompressedIR object at 0x7f8a2b54a2d0>, 'tree': <ContractionTree(N=638, branches=15, complete=False)>}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'compress': CategoricalDistribution(choices=('qubits', '2q', 'none')), 'choose_leaf': CategoricalDistribution(choices=('qubits',)), 'random_strength': FloatDistribution(high=10.0, log=False, low=0.01, step=None), 'weight_edges' ...
# [9190.0, 0.990247378264551]
