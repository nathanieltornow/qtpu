# %%
from catalyst import qjit, measure, cond, for_loop, while_loop
import pennylane as qml
from jax import numpy as jnp

# %%
from jax.core import ShapedArray

@qjit  # compilation happens at definition
@qml.qnode(qml.device("lightning.qubit", wires=2))
def circuit(x: complex, z: ShapedArray(shape=(3,), dtype=jnp.float64)):
    theta = jnp.abs(x)
    qml.RY(theta, wires=0)
    qml.Rot(z[0], z[1], z[2], wires=0)
    return qml.state()
# Out:
# ---------------------------------------------------------------------------
# CompileError                              Traceback (most recent call last)
# Cell In[3], line 3
#       1 from jax.core import ShapedArray
# ----> 3 @qjit  # compilation happens at definition
#       4 @qml.qnode(qml.device("lightning.qubit", wires=2))
#       5 def circuit(x: complex, z: ShapedArray(shape=(3,), dtype=jnp.float64)):
#       6     theta = jnp.abs(x)
#       7     qml.RY(theta, wires=0)
#
# File ~/qvm/.venv/lib/python3.11/site-packages/catalyst/jit.py:734, in qjit(fn, autograph, async_qnodes, target, keep_intermediate, verbose, logfile, pipelines, static_argnums, abstracted_axes)
#     731 if fn is None:
#     732     return functools.partial(qjit, **kwargs)
# --> 734 return QJIT(fn, CompileOptions(**kwargs))
#
# File ~/qvm/.venv/lib/python3.11/site-packages/catalyst/jit.py:103, in QJIT.__init__(self, fn, compile_options)
#     101 # Static arguments require values, so we cannot AOT compile.
#     102 if self.user_sig is not None and not self.compile_options.static_argnums:
# --> 103     self.aot_compile()
#
# File ~/qvm/.venv/lib/python3.11/site-packages/catalyst/jit.py:137, in QJIT.aot_compile(self)
#     134     self.mlir_module, self.mlir = self.generate_ir()
#     136 if self.compile_options.target in ("binary",):
# --> 137     self.compiled_function, self.qir = self.compile()
#     138     self.fn_cache.insert(
#     139         self.compiled_function, self.user_sig, self.out_treedef, self.workspace
#     140     )
#
# File ~/qvm/.venv/lib/python3.11/site-packages/catalyst/debug/instruments.py:143, in instrument.<locals>.wrapper(*args, **kwargs)
#     140 @functools.wraps(fn)
#     141 def wrapper(*args, **kwargs):
#     142     if not InstrumentSession.active:
# --> 143         return fn(*args, **kwargs)
#     145     with ResultReporter(stage_name, has_finegrained) as reporter:
#     146         fn_results, wall_time, cpu_time = time_function(fn, args, kwargs)
#
# File ~/qvm/.venv/lib/python3.11/site-packages/catalyst/jit.py:277, in QJIT.compile(self)
#     273 # The function name out of MLIR has quotes around it, which we need to remove.
#     274 # The MLIR function name is actually a derived type from string which has no
#     275 # `replace` method, so we need to get a regular Python string out of it.
#     276 func_name = str(self.mlir_module.body.operations[0].name).replace('"', "")
# --> 277 shared_object, llvm_ir, _ = self.compiler.run(self.mlir_module, self.workspace)
#     278 compiled_fn = CompiledFunction(shared_object, func_name, restype, self.compile_options)
#     280 return compiled_fn, llvm_ir
#
# File ~/qvm/.venv/lib/python3.11/site-packages/catalyst/compiler.py:522, in Compiler.run(self, mlir_module, *args, **kwargs)
#     507 def run(self, mlir_module, *args, **kwargs):
#     508     """Compile an MLIR module to a shared object.
#     509
#     510     .. note::
#    (...)
#     519         (str): filename of shared object
#     520     """
# --> 522     return self.run_from_ir(
#     523         mlir_module.operation.get_asm(
#     524             binary=False, print_generic_op_form=False, assume_verified=True
#     525         ),
#     526         str(mlir_module.operation.attributes["sym_name"]).replace('"', ""),
#     527         *args,
#     528         **kwargs,
#     529     )
#
# File ~/qvm/.venv/lib/python3.11/site-packages/catalyst/compiler.py:499, in Compiler.run_from_ir(self, ir, module_name, workspace)
#     496 ret_type_name = compiler_output.get_function_attributes().get_return_type()
#     498 if lower_to_llvm:
# --> 499     output = LinkerDriver.run(filename, options=self.options)
#     500     output_filename = str(pathlib.Path(output).absolute())
#     501 else:
#
# File ~/qvm/.venv/lib/python3.11/site-packages/catalyst/compiler.py:437, in LinkerDriver.run(infile, outfile, flags, fallback_compilers, options)
#     435 msg = f"Unable to link {infile}. Please check the output for any error messages. If no "
#     436 msg += "compiler was found by Catalyst, please specify a compatible one via $CATALYST_CC."
# --> 437 raise CompileError(msg)
#
# CompileError: Unable to link /tmp/circuitp8qpmbp7/circuit.o. Please check the output for any error messages. If no compiler was found by Catalyst, please specify a compatible one via $CATALYST_CC.
