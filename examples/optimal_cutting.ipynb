# %%
from _example_circuit import example_circuit
from qvm.core import cut, fragment_circuit


circuit = example_circuit()

virt_circuit = cut(
    circuit,
    technique="optimal",
    num_fragments=3,
    max_wire_cuts=0,
    max_gate_cuts=4,
    # max_fragment_size=7,
)
fragment_circuit(virt_circuit).draw(output="mpl")
